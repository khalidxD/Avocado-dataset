# %% [markdown]
# # Analyze Avocado Dataset

# %% [markdown]
# ## Details:
# * Date - The date of the observation.
# * AveragePrice - the average price of a single avocado
# * type - conventional or organic
# * year - the year
# * Region - the city or region of the observation
# * Total Volume - Total number of avocados sold
# * 4046 - Total number of avocados with PLU 4046 sold
# * 4225 - Total number of avocados with PLU 4225 sold
# * 4770 - Total number of avocados with PLU 4770 sold

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Q1: Read your dataset, and using a dedicated pandas function view the first 5 rows
df=pd.read_csv('/Users/immortal/Desktop/DataScience/DataScienceCourse/Analysis/data/Avocado.csv')
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
# Q2: gain insights of your data set and see general information about each feature and the total number of non-null values in each variable
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
# Q3: use a dedicated pandas function that gives summary statstics for only intersting numerical features in your data set.
df.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean    9124.000000      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std     5268.176867      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%     4562.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%     9124.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%    13686.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max    18248.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %%
# Q4: Can you dedect the missleading value from the above summary statstics?

# %%
# Q5: Let us now look at the datatypes of all these columns.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244       18244  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245       18245  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246       18246  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247       18247  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248       18248  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
# Q6: Sort your data set by Date column
df['Date']=pd.to_datetime(df['Date']) # Convert The date into datetime
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  datetime64[ns]
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: datetime64[ns](1), float64(9), int64(2), object(2)
# memory usage: 1.9+ MB

# %%
df=df.sort_values(by='Date')
df
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume        4046  \
# 11569       11569 2015-01-04          1.75      27365.89     9307.34
# 9593         9593 2015-01-04          1.49      17723.17     1189.35
# 10009       10009 2015-01-04          1.68       2896.72      161.68
# 1819         1819 2015-01-04          1.52      54956.80     3013.04
# 9333         9333 2015-01-04          1.64       1505.12        1.27
# ...           ...        ...           ...           ...         ...
# 8574         8574 2018-03-25          1.36     908202.13   142681.06
# 9018         9018 2018-03-25          0.70    9010588.32  3999735.71
# 18141       18141 2018-03-25          1.42     163496.70    29253.30
# 17673       17673 2018-03-25          1.70     190257.38    29644.09
# 8814         8814 2018-03-25          1.34    1774776.77    63905.98
#
#             4225       4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
# Q7: Check for unique values of all columns.
for i in df.columns:
    print(i)
    print(df[i].unique())
# Out:
# Unnamed: 0
# [11569  9593 10009 ... 18141 17673  8814]
# Date
# ['2015-01-04T00:00:00.000000000' '2015-01-11T00:00:00.000000000'
#  '2015-01-18T00:00:00.000000000' '2015-01-25T00:00:00.000000000'
#  '2015-02-01T00:00:00.000000000' '2015-02-08T00:00:00.000000000'
#  '2015-02-15T00:00:00.000000000' '2015-02-22T00:00:00.000000000'
#  '2015-03-01T00:00:00.000000000' '2015-03-08T00:00:00.000000000'
#  '2015-03-15T00:00:00.000000000' '2015-03-22T00:00:00.000000000'
#  '2015-03-29T00:00:00.000000000' '2015-04-05T00:00:00.000000000'
#  '2015-04-12T00:00:00.000000000' '2015-04-19T00:00:00.000000000'
#  '2015-04-26T00:00:00.000000000' '2015-05-03T00:00:00.000000000'
#  '2015-05-10T00:00:00.000000000' '2015-05-17T00:00:00.000000000'
#  '2015-05-24T00:00:00.000000000' '2015-05-31T00:00:00.000000000'
#  '2015-06-07T00:00:00.000000000' '2015-06-14T00:00:00.000000000'
#  '2015-06-21T00:00:00.000000000' '2015-06-28T00:00:00.000000000'
# ...

# %%
# Q8: what is the average price for each region for the year 2018?


df[df['year']==2018].groupby(['region'])['AveragePrice'].sum()
# Out:
# region
# Albany                 34.46
# Atlanta                30.93
# BaltimoreWashington    33.08
# Boise                  35.82
# Boston                 37.84
# BuffaloRochester       29.43
# California             33.87
# Charlotte              35.58
# Chicago                37.48
# CincinnatiDayton       30.62
# Columbus               28.12
# DallasFtWorth          26.47
# Denver                 30.74
# Detroit                28.27
# GrandRapids            31.88
# GreatLakes             30.68
# HarrisburgScranton     32.08
# HartfordSpringfield    40.26
# Houston                25.01
# Indianapolis           28.04
# Jacksonville           34.96
# LasVegas               33.45
# LosAngeles             32.44
# Louisville             30.43
# MiamiFtLauderdale      32.26
# Midsouth               32.60
# Nashville              29.34
# NewOrleansMobile       28.90
# NewYork                37.79
# Northeast              35.38
# NorthernNewEngland     34.11
# ...

# %%
# Q9 : How much was the total of average price for each year for the organic type?

df[df['type']=='organic'].groupby(['year','type'])['AveragePrice'].sum()
# Out:
# year  type
# 2015  organic    4697.02
# 2016  organic    4413.29
# 2017  organic    4963.59
# 2018  organic    1015.53
# Name: AveragePrice, dtype: float64

# %%
df
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume        4046  \
# 11569       11569 2015-01-04          1.75      27365.89     9307.34
# 9593         9593 2015-01-04          1.49      17723.17     1189.35
# 10009       10009 2015-01-04          1.68       2896.72      161.68
# 1819         1819 2015-01-04          1.52      54956.80     3013.04
# 9333         9333 2015-01-04          1.64       1505.12        1.27
# ...           ...        ...           ...           ...         ...
# 8574         8574 2018-03-25          1.36     908202.13   142681.06
# 9018         9018 2018-03-25          0.70    9010588.32  3999735.71
# 18141       18141 2018-03-25          1.42     163496.70    29253.30
# 17673       17673 2018-03-25          1.70     190257.38    29644.09
# 8814         8814 2018-03-25          1.34    1774776.77    63905.98
#
#             4225       4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
# Q10: How much was the Average price for each month of each region? To  do this you may want to create column feature, we created
      # a function for you just apply it, and in the next cell you will do the computation
df['month']=df['Date'].dt.month
df
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume        4046  \
# 11569       11569 2015-01-04          1.75      27365.89     9307.34
# 9593         9593 2015-01-04          1.49      17723.17     1189.35
# 10009       10009 2015-01-04          1.68       2896.72      161.68
# 1819         1819 2015-01-04          1.52      54956.80     3013.04
# 9333         9333 2015-01-04          1.64       1505.12        1.27
# ...           ...        ...           ...           ...         ...
# 8574         8574 2018-03-25          1.36     908202.13   142681.06
# 9018         9018 2018-03-25          0.70    9010588.32  3999735.71
# 18141       18141 2018-03-25          1.42     163496.70    29253.30
# 17673       17673 2018-03-25          1.70     190257.38    29644.09
# 8814         8814 2018-03-25          1.34    1774776.77    63905.98
#
#             4225       4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
# Q11: now compute the total of Average price for each month of each region.
df.groupby(['region','month'])['AveragePrice'].sum()
# Out:
# region            month
# Albany            1        55.37
#                   2        47.09
#                   3        51.65
#                   4        40.27
#                   5        44.24
#                            ...
# WestTexNewMexico  8        36.03
#                   9        36.85
#                   10       45.69
#                   11       35.60
#                   12       30.56
# Name: AveragePrice, Length: 648, dtype: float64

# %%
# Q12: using .loc[], select the row with maximum Average Price
df.loc[:,'AveragePrice'].max()
# Out:
# 3.25

# %%
# Q13: Create a summary table description table reflecting each region and its total bags.
df.groupby(['region'])['Total Bags'].sum()
# Out:
# region
# Albany                 2.680255e+06
# Atlanta                2.856051e+07
# BaltimoreWashington    3.530615e+07
# Boise                  5.399412e+06
# Boston                 2.149548e+07
# BuffaloRochester       1.161075e+07
# California             2.466822e+08
# Charlotte              1.169794e+07
# Chicago                1.686540e+07
# CincinnatiDayton       2.089792e+07
# Columbus               1.001639e+07
# DallasFtWorth          4.646975e+07
# Denver                 5.895701e+07
# Detroit                2.426007e+07
# GrandRapids            9.169094e+06
# GreatLakes             1.785756e+08
# HarrisburgScranton     1.352925e+07
# HartfordSpringfield    1.133301e+07
# Houston                5.021506e+07
# Indianapolis           1.198081e+07
# Jacksonville           9.718127e+06
# LasVegas               1.805299e+07
# LosAngeles             1.682645e+08
# Louisville             6.635289e+06
# MiamiFtLauderdale      2.351644e+07
# Midsouth               1.565136e+08
# ...

# %%
# Q14: which type corresponds for highest total Average Price?
df.groupby(['type'])['AveragePrice'].sum()
# The answer is organic
# Out:
# type
# conventional    10568.27
# organic         15089.43
# Name: AveragePrice, dtype: float64

# %%
# Q14: what is the total of average price for each region for the organic type?

df[df['type']=='organic'].groupby(['type','region'])['AveragePrice'].sum()
# Out:
# type     region
# organic  Albany                 299.69
#          Atlanta                271.60
#          BaltimoreWashington    291.40
#          Boise                  273.82
#          Boston                 297.00
#          BuffaloRochester       279.08
#          California             284.80
#          Charlotte              327.35
#          Chicago                294.77
#          CincinnatiDayton       237.09
#          Columbus               243.24
#          DallasFtWorth          223.88
#          Denver                 230.38
#          Detroit                241.37
#          GrandRapids            284.76
#          GreatLakes             252.69
#          HarrisburgScranton     298.75
#          HartfordSpringfield    376.74
#          Houston                214.76
#          Indianapolis           250.65
#          Jacksonville           308.98
#          LasVegas               295.56
#          LosAngeles             245.99
# ...

# %%
df
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume        4046  \
# 11569       11569 2015-01-04          1.75      27365.89     9307.34
# 9593         9593 2015-01-04          1.49      17723.17     1189.35
# 10009       10009 2015-01-04          1.68       2896.72      161.68
# 1819         1819 2015-01-04          1.52      54956.80     3013.04
# 9333         9333 2015-01-04          1.64       1505.12        1.27
# ...           ...        ...           ...           ...         ...
# 8574         8574 2018-03-25          1.36     908202.13   142681.06
# 9018         9018 2018-03-25          0.70    9010588.32  3999735.71
# 18141       18141 2018-03-25          1.42     163496.70    29253.30
# 17673       17673 2018-03-25          1.70     190257.38    29644.09
# 8814         8814 2018-03-25          1.34    1774776.77    63905.98
#
#             4225       4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
# Q15: creat a pivot table showing total of Average price for each month indexed by year.
df.pivot_table(values='AveragePrice', index='year', columns='month')
# Out:
# month        1         2         3         4         5         6         7   \
# year
# 2015   1.365046  1.326944  1.361981  1.383449  1.344685  1.399074  1.409444
# 2016   1.240185  1.237106  1.224213  1.205023  1.199722  1.283056  1.401333
# 2017   1.277500  1.214792  1.398935  1.502611  1.532593  1.545395  1.564926
# 2018   1.387431  1.318704  1.336458       NaN       NaN       NaN       NaN
#
# month        8         9         10        11        12
# year
# 2015   1.444481  1.449144  1.391968  1.330611  1.305244
# 2016   1.411111  1.427870  1.557093  1.550023  1.315995
# 2017   1.698958  1.840949  1.752444  1.517292  1.363852
# 2018        NaN       NaN       NaN       NaN       NaN

# %%
# Q16: creat a pivot table showing total of Average price for each month indexed by year and type.
df.pivot_table(values='AveragePrice', index=['year','type'], columns='month')
# Out:
# month                    1         2         3         4         5         6   \
# year type
# 2015 conventional  1.092454  1.055324  1.089889  1.116852  1.090519  1.086481
#      organic       1.637639  1.598565  1.634074  1.650046  1.598852  1.711667
# 2016 conventional  0.985926  0.937315  1.001296  0.961111  0.936222  1.072546
#      organic       1.494444  1.536898  1.447130  1.448935  1.463222  1.493565
# 2017 conventional  1.043556  1.005231  1.292083  1.307741  1.280093  1.288565
#      organic       1.511444  1.424352  1.505787  1.697481  1.785093  1.804626
# 2018 conventional  1.181620  1.071389  1.130648       NaN       NaN       NaN
#      organic       1.593241  1.566019  1.542269       NaN       NaN       NaN
#
# month                    7         8         9         10        11        12
# year type
# 2015 conventional  1.113889  1.117037  1.075278  1.063981  1.024963  1.006250
#      organic       1.705000  1.771926  1.823009  1.719954  1.636259  1.605628
# ...

# %%
# Q17: Correlation between 'Total Volume','Total Bags' and 'AveragePrice'.
df.corr()
# Out:
#               Unnamed: 0  AveragePrice  Total Volume      4046      4225  \
# Unnamed: 0      1.000000      0.580381     -0.168399 -0.166754 -0.184919
# AveragePrice    0.580381      1.000000     -0.192752 -0.208317 -0.172928
# Total Volume   -0.168399     -0.192752      1.000000  0.977863  0.974181
# 4046           -0.166754     -0.208317      0.977863  1.000000  0.926110
# 4225           -0.184919     -0.172928      0.974181  0.926110  1.000000
# 4770           -0.185293     -0.179446      0.872202  0.833389  0.887855
# Total Bags     -0.129843     -0.177088      0.963047  0.920057  0.905787
# Small Bags     -0.137199     -0.174730      0.967238  0.925280  0.916031
# Large Bags     -0.097898     -0.172940      0.880640  0.838645  0.810015
# XLarge Bags    -0.101623     -0.117592      0.747157  0.699377  0.688809
# year            0.475101      0.093197      0.017193  0.003353 -0.009559
# month          -0.074877      0.162409     -0.024689 -0.025803 -0.022108
#
# ...

# %%
# Q18: drop the 'Small Bags' feature.
del df['Small Bags']
df
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume        4046  \
# 11569       11569 2015-01-04          1.75      27365.89     9307.34
# 9593         9593 2015-01-04          1.49      17723.17     1189.35
# 10009       10009 2015-01-04          1.68       2896.72      161.68
# 1819         1819 2015-01-04          1.52      54956.80     3013.04
# 9333         9333 2015-01-04          1.64       1505.12        1.27
# ...           ...        ...           ...           ...         ...
# 8574         8574 2018-03-25          1.36     908202.13   142681.06
# 9018         9018 2018-03-25          0.70    9010588.32  3999735.71
# 18141       18141 2018-03-25          1.42     163496.70    29253.30
# 17673       17673 2018-03-25          1.70     190257.38    29644.09
# 8814         8814 2018-03-25          1.34    1774776.77    63905.98
#
#             4225       4770  Total Bags  Large Bags  XLarge Bags  \
# 11569    3844.81     615.28    13598.46      537.36         0.00
# ...

# %%
# Q19: save your data set with .csv format for later use.
df.to_csv('/Users/immortal/Desktop/DataScience/DataScienceCourse/Analysis/data/newAvocado.csv')

# %%
# Q20: if you were in charge to gather more data to help you better tackle down the problem, what features you might need?


#The stores that sell the product ,To see what is correlation between The avarage price and stores and what is the profit from these stores

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# #### Q1: check distribution of average price during Jan 2018

# %%
df[(df['month']==1)&(df['year']==2018)]['AveragePrice']
# Out:
# 17780    1.25
# 17768    1.22
# 17756    1.38
# 17744    1.45
# 17732    1.15
#          ...
# 18173    1.70
# 8822     1.20
# 17729    1.43
# 8918     1.34
# 9002     1.34
# Name: AveragePrice, Length: 432, dtype: float64

# %%
plt.hist(df[(df['month']==1)&(df['year']==2018)]['AveragePrice'])
# Out:
# (array([10., 25., 71., 90., 82., 67., 52., 22., 10.,  3.]),
#  array([0.68 , 0.842, 1.004, 1.166, 1.328, 1.49 , 1.652, 1.814, 1.976,
#         2.138, 2.3  ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #### Q2: using diffrent chart than you used in the previous one, plot the distribution for Jan 2018 Average price

# %%
sns.distplot(df[(df['month']==1)&(df['year']==2018)]['AveragePrice'])
# Out:
# /Users/immortal/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='AveragePrice', ylabel='Density'>

# %% [markdown]
# #### Q3: Create box-plot for the Average price, but this time for all the dataset, and comment your conclusion

# %%
plt.boxplot(df[(df['month']==1)&(df['year']==2018)]['AveragePrice']) # The hole data is between 1.6 and 1.2 and the outliers is above 2.1 and under 0.8
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7faaa9352730>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7faaa9352970>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7faaa9352400>],
#  'medians': [<matplotlib.lines.Line2D at 0x7faaa9352ac0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7faaa9242d00>],
#  'means': []}

# %% [markdown]
# # Bi/Multivariate

# %% [markdown]
# #### Q4: Create a tracing boxplots (multiple box-plots in one figure) that shows the average price for each month and colored by year to distnguish between them

# %%
sns.boxplot(x='month',y='AveragePrice',data=df , hue='year')
# Out:
# <AxesSubplot:xlabel='month', ylabel='AveragePrice'>

# %% [markdown]
# #### Q5: compare between average prcies of diffrent types of producs

# %%
plt.bar(df['type'] , df['AveragePrice'])
#from the grapgh we see the organic is the best selling
# Out:
# <BarContainer object of 18249 artists>

# %% [markdown]
# #### Q6:what are the top 10 best selling region with pandas and with a chart?

# %%
df.groupby(['region'])['AveragePrice'].sum().sort_values(ascending=False)[0:10] #this is the best 10 regions selling with pandas
# Out:
# region
# HartfordSpringfield    614.70
# SanFrancisco           609.82
# NewYork                583.92
# Philadelphia           551.66
# Sacramento             548.09
# Charlotte              542.84
# Northeast              541.45
# Albany                 527.63
# Chicago                526.19
# RaleighGreensboro      525.63
# Name: AveragePrice, dtype: float64

# %%
plt.bar(df['region'] , df['AveragePrice'])
# Out:
# <BarContainer object of 18249 artists>

# %% [markdown]
# #### Q7 : Create multiple a heat map to compare between Average Price for each month for each year.

# %%
sns.heatmap(df.pivot_table(values='AveragePrice', index='year', columns='month'))
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %% [markdown]
# #### Q9 : Create bar chart group for each year, reflects Average Price in each month

# %%
plt.bar(df['year'] ,df['AveragePrice'] )
# Out:
# <BarContainer object of 18249 artists>

# %% [markdown]
# #### Create a new column for profit

# %%
df['profit']=df['AveragePrice']*df['Total Volume']
df
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume        4046  \
# 11569       11569 2015-01-04          1.75      27365.89     9307.34
# 9593         9593 2015-01-04          1.49      17723.17     1189.35
# 10009       10009 2015-01-04          1.68       2896.72      161.68
# 1819         1819 2015-01-04          1.52      54956.80     3013.04
# 9333         9333 2015-01-04          1.64       1505.12        1.27
# ...           ...        ...           ...           ...         ...
# 8574         8574 2018-03-25          1.36     908202.13   142681.06
# 9018         9018 2018-03-25          0.70    9010588.32  3999735.71
# 18141       18141 2018-03-25          1.42     163496.70    29253.30
# 17673       17673 2018-03-25          1.70     190257.38    29644.09
# 8814         8814 2018-03-25          1.34    1774776.77    63905.98
#
#             4225       4770  Total Bags  Large Bags  XLarge Bags  \
# 11569    3844.81     615.28    13598.46      537.36         0.00
# ...

# %% [markdown]
# #### what is the best selling Month

# %%
df.groupby(['month'])['profit'].sum().sort_values(ascending=False)
#the best month selling is 1
# Out:
# month
# 1     1.771539e+09
# 3     1.730009e+09
# 2     1.648614e+09
# 7     1.529586e+09
# 5     1.515673e+09
# 8     1.343889e+09
# 10    1.342014e+09
# 4     1.327835e+09
# 6     1.312736e+09
# 9     1.207088e+09
# 12    1.107970e+09
# 11    1.097177e+09
# Name: profit, dtype: float64

# %% [markdown]
# ### For each month what is the most selling type

# %%
df.groupby(['month' ,'type'])['profit'].sum().sort_values(ascending=False ) # The most selling is conventional
# Out:
# month  type
# 1      conventional    1.705844e+09
# 3      conventional    1.654179e+09
# 2      conventional    1.582465e+09
# 7      conventional    1.472206e+09
# 5      conventional    1.456152e+09
# 8      conventional    1.292198e+09
# 10     conventional    1.287130e+09
# 4      conventional    1.271318e+09
# 6      conventional    1.262411e+09
# 9      conventional    1.157121e+09
# 12     conventional    1.061070e+09
# 11     conventional    1.051428e+09
# 3      organic         7.583001e+07
# 2      organic         6.614860e+07
# 1      organic         6.569540e+07
# 5      organic         5.952082e+07
# 7      organic         5.738026e+07
# 4      organic         5.651709e+07
# 10     organic         5.488454e+07
# 8      organic         5.169113e+07
# 6      organic         5.032509e+07
# 9      organic         4.996683e+07
# 12     organic         4.689922e+07
# 11     organic         4.574953e+07
# Name: profit, dtype: float64

# %% [markdown]
# # Q20: write the conclusion you came up with after your analysis, including your recommendations for the mangment to improve the business.

# %%
#The highest avarege price in avocado was in 2016 and the most selling is a conventional avocado. The most selling month for avocado was in Jan so he must increase the conventional avocado bags
#at this month for better profit The most region that sells an avocado is  SanFrancisco          NewYork               Philadelphia          Sacramento            Charlotte             Northeast 
#Albany                Chicago                RaleighGreensboro so he should focus on other regions to get more profit
